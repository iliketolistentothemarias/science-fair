# %% [markdown]
# # NSCLC EGFR Prediction Pipeline
#
# This notebook runs the full pipeline for predicting EGFR status from CT scans.
# It assumes the source code is present in the current directory.

# %%
# 1. Install Dependencies
# !pip install -r requirements.txt

# %%
# 2. Download Data (from TCIA)
# !python download_data.py

# %%
# 3. Run Experiment (Preprocessing -> Feature Extraction -> Training)
# !python run_experiment.py --run_all
